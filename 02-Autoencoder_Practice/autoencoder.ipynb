# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
from utils import load_mnist
from trainer import Trainer

# %%
from argparse import Namespace

config = {
    'train_ratio': .8,
    'batch_size': 256,
    'n_epochs': 50,
    'verbose': 1,
    'btl_size': 2
}

config = Namespace(**config)

print(config)
# Out:
# Namespace(batch_size=256, btl_size=2, n_epochs=50, train_ratio=0.8, verbose=1)

# %%
def show_image(x):
    if x.dim() == 1:
        x = x.view(int(x.size(0) ** 0.5), -1)
    
    plt.imshow(x, cmap='gray')
    plt.show()

# %%
train_x, train_y = load_mnist(flatten=True)
test_x, test_y = load_mnist(is_train=False, flatten=True)

train_cnt = int(train_x.size(0) * config.train_ratio)
valid_cnt = train_x.size(0) - train_cnt

# Shuffle dataset to split into train/valid set.
indices = torch.randperm(train_x.size(0))
train_x, valid_x = torch.index_select(
    train_x,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)
train_y, valid_y = torch.index_select(
    train_y,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)

print("Train:", train_x.shape, train_y.shape)
print("Valid:", valid_x.shape, valid_y.shape)
print("Test:", test_x.shape, test_y.shape)
# Out:
# Train: torch.Size([48000, 784]) torch.Size([48000])
# Valid: torch.Size([12000, 784]) torch.Size([12000])
# Test: torch.Size([10000, 784]) torch.Size([10000])

# %%
from model import Autoencoder

# %%
model = Autoencoder(btl_size=config.btl_size)
optimizer = optim.Adam(model.parameters())
crit = nn.MSELoss()

trainer = Trainer(model, optimizer, crit)

# %%
trainer.train((train_x, train_x), (valid_x, valid_x), config)
# Out:
# Epoch(1/50): train_loss=7.1565e-02  valid_loss=4.8470e-02  lowest_loss=4.8470e-02
# Epoch(2/50): train_loss=4.6481e-02  valid_loss=4.4383e-02  lowest_loss=4.4383e-02
# Epoch(3/50): train_loss=4.3842e-02  valid_loss=4.2559e-02  lowest_loss=4.2559e-02
# Epoch(4/50): train_loss=4.2778e-02  valid_loss=4.1860e-02  lowest_loss=4.1860e-02
# Epoch(5/50): train_loss=4.2143e-02  valid_loss=4.0912e-02  lowest_loss=4.0912e-02
# Epoch(6/50): train_loss=4.1578e-02  valid_loss=4.0674e-02  lowest_loss=4.0674e-02
# Epoch(7/50): train_loss=4.1376e-02  valid_loss=4.0273e-02  lowest_loss=4.0273e-02
# Epoch(8/50): train_loss=4.0739e-02  valid_loss=3.9453e-02  lowest_loss=3.9453e-02
# Epoch(9/50): train_loss=4.0382e-02  valid_loss=3.9468e-02  lowest_loss=3.9453e-02
# Epoch(10/50): train_loss=3.9910e-02  valid_loss=3.9050e-02  lowest_loss=3.9050e-02
# Epoch(11/50): train_loss=3.9777e-02  valid_loss=3.8751e-02  lowest_loss=3.8751e-02
# Epoch(12/50): train_loss=3.9512e-02  valid_loss=3.8704e-02  lowest_loss=3.8704e-02
# Epoch(13/50): train_loss=3.9365e-02  valid_loss=3.8645e-02  lowest_loss=3.8645e-02
# Epoch(14/50): train_loss=3.9210e-02  valid_loss=3.8448e-02  lowest_loss=3.8448e-02
# Epoch(15/50): train_loss=3.9014e-02  valid_loss=3.7700e-02  lowest_loss=3.7700e-02
# Epoch(16/50): train_loss=3.8523e-02  valid_loss=3.7824e-02  lowest_loss=3.7700e-02
# Epoch(17/50): train_loss=3.8793e-02  valid_loss=3.7850e-02  lowest_loss=3.7700e-02
# Epoch(18/50): train_loss=3.8454e-02  valid_loss=3.7866e-02  lowest_loss=3.7700e-02
# Epoch(19/50): train_loss=3.8654e-02  valid_loss=3.8404e-02  lowest_loss=3.7700e-02
# Epoch(20/50): train_loss=3.9026e-02  valid_loss=3.8488e-02  lowest_loss=3.7700e-02
# Epoch(21/50): train_loss=3.8817e-02  valid_loss=3.7679e-02  lowest_loss=3.7679e-02
# Epoch(22/50): train_loss=3.8430e-02  valid_loss=3.7483e-02  lowest_loss=3.7483e-02
# Epoch(23/50): train_loss=3.8299e-02  valid_loss=3.7461e-02  lowest_loss=3.7461e-02
# Epoch(24/50): train_loss=3.8317e-02  valid_loss=3.7506e-02  lowest_loss=3.7461e-02
# Epoch(25/50): train_loss=3.8008e-02  valid_loss=3.6961e-02  lowest_loss=3.6961e-02
# Epoch(26/50): train_loss=3.7890e-02  valid_loss=3.6772e-02  lowest_loss=3.6772e-02
# Epoch(27/50): train_loss=3.8124e-02  valid_loss=3.7345e-02  lowest_loss=3.6772e-02
# Epoch(28/50): train_loss=3.7698e-02  valid_loss=3.6977e-02  lowest_loss=3.6772e-02
# Epoch(29/50): train_loss=3.7831e-02  valid_loss=3.6597e-02  lowest_loss=3.6597e-02
# Epoch(30/50): train_loss=3.7524e-02  valid_loss=3.6812e-02  lowest_loss=3.6597e-02
# Epoch(31/50): train_loss=3.7258e-02  valid_loss=3.6659e-02  lowest_loss=3.6597e-02
# Epoch(32/50): train_loss=3.7272e-02  valid_loss=3.6212e-02  lowest_loss=3.6212e-02
# Epoch(33/50): train_loss=3.7368e-02  valid_loss=3.6206e-02  lowest_loss=3.6206e-02
# Epoch(34/50): train_loss=3.7781e-02  valid_loss=3.6817e-02  lowest_loss=3.6206e-02
# Epoch(35/50): train_loss=3.7433e-02  valid_loss=3.8234e-02  lowest_loss=3.6206e-02
# Epoch(36/50): train_loss=3.7808e-02  valid_loss=3.6851e-02  lowest_loss=3.6206e-02
# Epoch(37/50): train_loss=3.7284e-02  valid_loss=3.6642e-02  lowest_loss=3.6206e-02
# Epoch(38/50): train_loss=3.7578e-02  valid_loss=3.6827e-02  lowest_loss=3.6206e-02
# Epoch(39/50): train_loss=3.7187e-02  valid_loss=3.6440e-02  lowest_loss=3.6206e-02
# Epoch(40/50): train_loss=3.6856e-02  valid_loss=3.6489e-02  lowest_loss=3.6206e-02
# Epoch(41/50): train_loss=3.6964e-02  valid_loss=3.6503e-02  lowest_loss=3.6206e-02
# Epoch(42/50): train_loss=3.6818e-02  valid_loss=3.6035e-02  lowest_loss=3.6035e-02
# Epoch(43/50): train_loss=3.6973e-02  valid_loss=3.6172e-02  lowest_loss=3.6035e-02
# Epoch(44/50): train_loss=3.6779e-02  valid_loss=3.5798e-02  lowest_loss=3.5798e-02
# Epoch(45/50): train_loss=3.6448e-02  valid_loss=3.6394e-02  lowest_loss=3.5798e-02
# Epoch(46/50): train_loss=3.6796e-02  valid_loss=3.6259e-02  lowest_loss=3.5798e-02
# Epoch(47/50): train_loss=3.6938e-02  valid_loss=3.5760e-02  lowest_loss=3.5760e-02
# Epoch(48/50): train_loss=3.6544e-02  valid_loss=3.5829e-02  lowest_loss=3.5760e-02
# Epoch(49/50): train_loss=3.6661e-02  valid_loss=3.6116e-02  lowest_loss=3.5760e-02
# Epoch(50/50): train_loss=3.6743e-02  valid_loss=3.5865e-02  lowest_loss=3.5760e-02

# %% [markdown]
# ## Test

# %%
with torch.no_grad():
    import random

    index = int(random.random() * test_x.size(0))

    recon = model(test_x[index].view(1, -1)).squeeze()

    show_image(test_x[index])
    show_image(recon)

# %% [markdown]
# ## Latent Space

# %%
if config.btl_size == 2:
    color_map = [
        'brown', 'red', 'orange', 'yellow', 'green',
        'blue', 'navy', 'purple', 'gray', 'black',
    ]
    
    plt.figure(figsize=(20, 10))
    with torch.no_grad():
        latents = model.encoder(test_x[:1000])
        
        for i in range(10):
            target_latents = latents[test_y[:1000] == i]
            target_y = test_y[:1000][test_y[:1000] == i]
            plt.scatter(target_latents[:, 0],
                        target_latents[:, 1],
                        marker='o',
                        color=color_map[i],
                        label=i)
        
        plt.legend()
        plt.grid(axis='both')
        plt.show()

# %%
if config.btl_size == 2:
    min_range, max_range = -2., 2.
    n = 20
    step = (max_range - min_range) / float(n)
    
    with torch.no_grad():
        lines = []

        for v1 in np.arange(min_range, max_range, step):
            z = torch.stack([
                torch.FloatTensor([v1] * n),
                torch.FloatTensor([v2 for v2 in np.arange(min_range,
                                                          max_range, step)]),
            ], dim=-1)
            
            line = torch.clamp(model.decoder(z).view(n, 28, 28), 0, 1)
            line = torch.cat([line[i]] for i in range(n-1, 0, -1), dim=0)
            lines += [line]
            
        lines = torch.cat(lines, dim=-1)
        plt.figure(figsize=(20, 20))
        show_image(lines)
# Out:
#   File "<ipython-input-18-741ace5dbb22>", line 17
#     line = torch.cat([line[i]] for i in range(n-1, 0, -1), dim=0)
#                     ^
# SyntaxError: Generator expression must be parenthesized
