# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
from utils import load_mnist
from trainer import Trainer

# %%
from argparse import Namespace

config = {
    'train_ratio': .8,
    'batch_size': 256,
    'n_epochs': 50,
    'verbose': 1,
    'btl_size': 2
}

config = Namespace(**config)

print(config)
# Out:
# Namespace(batch_size=256, btl_size=2, n_epochs=50, train_ratio=0.8, verbose=1)

# %%
def show_image(x):
    if x.dim() == 1:
        x = x.view(int(x.size(0) ** 0.5), -1)
    
    plt.imshow(x, cmap='gray')
    plt.show()

# %%
train_x, train_y = load_mnist(flatten=True)
test_x, test_y = load_mnist(is_train=False, flatten=True)

train_cnt = int(train_x.size(0) * config.train_ratio)
valid_cnt = train_x.size(0) - train_cnt

# Shuffle dataset to split into train/valid set.
indices = torch.randperm(train_x.size(0))
train_x, valid_x = torch.index_select(
    train_x,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)
train_y, valid_y = torch.index_select(
    train_y,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)

print("Train:", train_x.shape, train_y.shape)
print("Valid:", valid_x.shape, valid_y.shape)
print("Test:", test_x.shape, test_y.shape)
# Out:
# Train: torch.Size([48000, 784]) torch.Size([48000])
# Valid: torch.Size([12000, 784]) torch.Size([12000])
# Test: torch.Size([10000, 784]) torch.Size([10000])

# %%
from model import Autoencoder

# %%
model = Autoencoder(btl_size=config.btl_size)
optimizer = optim.Adam(model.parameters())
crit = nn.MSELoss()

trainer = Trainer(model, optimizer, crit)

# %%
trainer.train((train_x, train_x), (valid_x, valid_x), config)
# Out:
# Epoch(1/50): train_loss=7.1048e-02  valid_loss=4.8066e-02  lowest_loss=4.8066e-02
# Epoch(2/50): train_loss=4.6655e-02  valid_loss=4.4432e-02  lowest_loss=4.4432e-02
# Epoch(3/50): train_loss=4.4461e-02  valid_loss=4.3263e-02  lowest_loss=4.3263e-02
# Epoch(4/50): train_loss=4.3458e-02  valid_loss=4.1844e-02  lowest_loss=4.1844e-02
# Epoch(5/50): train_loss=4.2897e-02  valid_loss=4.2254e-02  lowest_loss=4.1844e-02
# Epoch(6/50): train_loss=4.1933e-02  valid_loss=4.0507e-02  lowest_loss=4.0507e-02
# Epoch(7/50): train_loss=4.1313e-02  valid_loss=4.0453e-02  lowest_loss=4.0453e-02
# Epoch(8/50): train_loss=4.1113e-02  valid_loss=3.9524e-02  lowest_loss=3.9524e-02
# Epoch(9/50): train_loss=4.0703e-02  valid_loss=3.9211e-02  lowest_loss=3.9211e-02
# Epoch(10/50): train_loss=4.0425e-02  valid_loss=3.9411e-02  lowest_loss=3.9211e-02
# Epoch(11/50): train_loss=4.0296e-02  valid_loss=3.9323e-02  lowest_loss=3.9211e-02
# Epoch(12/50): train_loss=4.0055e-02  valid_loss=3.9058e-02  lowest_loss=3.9058e-02
# Epoch(13/50): train_loss=3.9926e-02  valid_loss=3.8632e-02  lowest_loss=3.8632e-02
# Epoch(14/50): train_loss=3.9709e-02  valid_loss=3.8468e-02  lowest_loss=3.8468e-02
# Epoch(15/50): train_loss=3.9798e-02  valid_loss=3.8920e-02  lowest_loss=3.8468e-02
# Epoch(16/50): train_loss=3.9327e-02  valid_loss=3.8572e-02  lowest_loss=3.8468e-02
# Epoch(17/50): train_loss=3.9280e-02  valid_loss=3.7953e-02  lowest_loss=3.7953e-02
# Epoch(18/50): train_loss=3.9333e-02  valid_loss=3.8568e-02  lowest_loss=3.7953e-02
# Epoch(19/50): train_loss=3.9025e-02  valid_loss=3.7748e-02  lowest_loss=3.7748e-02
# Epoch(20/50): train_loss=3.9016e-02  valid_loss=3.8310e-02  lowest_loss=3.7748e-02
# Epoch(21/50): train_loss=3.8794e-02  valid_loss=3.7373e-02  lowest_loss=3.7373e-02
# Epoch(22/50): train_loss=3.8859e-02  valid_loss=3.7294e-02  lowest_loss=3.7294e-02
# Epoch(23/50): train_loss=3.8330e-02  valid_loss=3.6990e-02  lowest_loss=3.6990e-02
# Epoch(24/50): train_loss=3.8181e-02  valid_loss=3.7466e-02  lowest_loss=3.6990e-02
# Epoch(25/50): train_loss=3.8190e-02  valid_loss=3.7181e-02  lowest_loss=3.6990e-02
# Epoch(26/50): train_loss=3.8080e-02  valid_loss=3.6877e-02  lowest_loss=3.6877e-02
# Epoch(27/50): train_loss=3.8182e-02  valid_loss=3.6967e-02  lowest_loss=3.6877e-02
# Epoch(28/50): train_loss=3.7872e-02  valid_loss=3.7607e-02  lowest_loss=3.6877e-02
# Epoch(29/50): train_loss=3.7851e-02  valid_loss=3.6539e-02  lowest_loss=3.6539e-02
# Epoch(30/50): train_loss=3.7619e-02  valid_loss=3.7468e-02  lowest_loss=3.6539e-02
# Epoch(31/50): train_loss=3.7951e-02  valid_loss=3.6536e-02  lowest_loss=3.6536e-02
# Epoch(32/50): train_loss=3.7621e-02  valid_loss=3.6384e-02  lowest_loss=3.6384e-02
# Epoch(33/50): train_loss=3.7361e-02  valid_loss=3.6042e-02  lowest_loss=3.6042e-02
# Epoch(34/50): train_loss=3.7242e-02  valid_loss=3.6265e-02  lowest_loss=3.6042e-02
# Epoch(35/50): train_loss=3.7457e-02  valid_loss=3.7826e-02  lowest_loss=3.6042e-02
# Epoch(36/50): train_loss=3.7908e-02  valid_loss=3.6449e-02  lowest_loss=3.6042e-02
# Epoch(37/50): train_loss=3.7335e-02  valid_loss=3.7236e-02  lowest_loss=3.6042e-02
# Epoch(38/50): train_loss=3.8027e-02  valid_loss=3.8441e-02  lowest_loss=3.6042e-02
# Epoch(39/50): train_loss=3.7981e-02  valid_loss=3.6970e-02  lowest_loss=3.6042e-02
# Epoch(40/50): train_loss=3.7769e-02  valid_loss=3.6351e-02  lowest_loss=3.6042e-02
# Epoch(41/50): train_loss=3.7348e-02  valid_loss=3.6647e-02  lowest_loss=3.6042e-02
# Epoch(42/50): train_loss=3.7304e-02  valid_loss=3.6968e-02  lowest_loss=3.6042e-02
# Epoch(43/50): train_loss=3.6964e-02  valid_loss=3.6026e-02  lowest_loss=3.6026e-02
# Epoch(44/50): train_loss=3.7274e-02  valid_loss=3.5804e-02  lowest_loss=3.5804e-02
# Epoch(45/50): train_loss=3.6797e-02  valid_loss=3.5698e-02  lowest_loss=3.5698e-02
# Epoch(46/50): train_loss=3.6918e-02  valid_loss=3.5518e-02  lowest_loss=3.5518e-02
# Epoch(47/50): train_loss=3.6932e-02  valid_loss=3.6281e-02  lowest_loss=3.5518e-02
# Epoch(48/50): train_loss=3.7517e-02  valid_loss=3.6526e-02  lowest_loss=3.5518e-02
# Epoch(49/50): train_loss=3.7013e-02  valid_loss=3.5420e-02  lowest_loss=3.5420e-02
# Epoch(50/50): train_loss=3.6545e-02  valid_loss=3.5391e-02  lowest_loss=3.5391e-02

# %% [markdown]
# ## Test

# %%
with torch.no_grad():
    import random

    index = int(random.random() * test_x.size(0))

    recon = model(test_x[index].view(1, -1)).squeeze()

    show_image(test_x[index])
    show_image(recon)

# %% [markdown]
# ## Latent Space

# %%
if config.btl_size == 2:
    color_map = [
        'brown', 'red', 'orange', 'yellow', 'green',
        'blue', 'navy', 'purple', 'gray', 'black',
    ]
    
    plt.figure(figsize=(20, 10))
    with torch.no_grad():
        latents = model.encoder(test_x[:1000])
        
        for i in range(10):
            target_latents = latents[test_y[:1000] == i]
            target_y = test_y[:1000][test_y[:1000] == i]
            plt.scatter(target_latents[:, 0],
                        target_latents[:, 1],
                        marker='o',
                        color=color_map[i],
                        label=i)
        
        plt.legend()
        plt.grid(axis='both')
        plt.show()

# %%
if config.btl_size == 2:
    min_range, max_range = -2., 2.
    n = 20
    step = (max_range - min_range) / float(n)
    
    with torch.no_grad():
        lines = []

        for v1 in np.arange(min_range, max_range, step):
            z = torch.stack([
                torch.FloatTensor([v1] * n),
                torch.FloatTensor([v2 for v2 in np.arange(min_range,
                                                          max_range, step)]),
            ], dim=-1)
            
            line = torch.clamp(model.decoder(z).view(n, 28, 28), 0, 1)
            line = torch.cat([line[i] for i in range(n-1, 0, -1)], dim=0)
            lines += [line]
            
        lines = torch.cat(lines, dim=-1)
        plt.figure(figsize=(20, 20))
        show_image(lines)
